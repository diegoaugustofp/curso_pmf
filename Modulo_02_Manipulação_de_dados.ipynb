# %% [markdown]
# <a href="https://colab.research.google.com/github/diegoaugustofp/curso_pmf/blob/main/Modulo_02_Manipula%C3%A7%C3%A3o_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><img src = "https://github.com/Trading-com-Dados/pmf/blob/main/PMF%20002.png?raw=true" width = "700">

# %% [markdown]
# # Modulo 2 - Manipulação de Dados em Python

# %% [markdown]
# ## 1 Noções básicas de obtenção e processamento de dados

# %% [markdown]
# principais bibliotecas
#
# https://pandas.pydata.org
#
# https://wesmckinney.com

# %%
import pandas as pd

# %% [markdown]
# ### 1.1 Obtenção de dados vias arquivos

# %% [markdown]
# #### 1.1.1 - CSV

# %%
petro = pd.read_csv('/content/PETR4.csv')

# %%
petro
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2000-01-03   5.875000   5.875000   5.875000   5.875000   1.872027
# 1     2000-01-04   5.550000   5.550000   5.550000   5.550000   1.768469
# 2     2000-01-05   5.494000   5.494000   5.494000   5.494000   1.750625
# 3     2000-01-06   5.475000   5.475000   5.475000   5.475000   1.744570
# 4     2000-01-07   5.500000   5.500000   5.500000   5.500000   1.752536
# ...          ...        ...        ...        ...        ...        ...
# 5765  2022-12-13  24.100000  24.200001  23.309999  23.320000  23.320000
# 5766  2022-12-14  22.500000  22.600000  20.770000  21.469999  21.469999
# 5767  2022-12-15  21.000000  22.370001  20.830000  22.040001  22.040001
# 5768  2022-12-16  21.959999  22.110001  21.510000  22.049999  22.049999
# 5769  2022-12-19  22.100000  22.469999  21.639999  22.350000  22.350000
#
#            Volume
# 0     35389440000
# 1     28861440000
# 2     43033600000
# 3     34055680000
# ...

# %%
type(petro)
# Out:
# pandas.core.frame.DataFrame

# %%
petro.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close       Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1  2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2  2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3  2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4  2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
petro.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 5765  2022-12-13  24.100000  24.200001  23.309999  23.320000  23.320000
# 5766  2022-12-14  22.500000  22.600000  20.770000  21.469999  21.469999
# 5767  2022-12-15  21.000000  22.370001  20.830000  22.040001  22.040001
# 5768  2022-12-16  21.959999  22.110001  21.510000  22.049999  22.049999
# 5769  2022-12-19  22.100000  22.469999  21.639999  22.350000  22.350000
#
#          Volume
# 5765  102533100
# 5766  319501600
# 5767  132385600
# 5768   90767300
# 5769   37837300

# %%
petro.Close.plot();

# %%
petro['Close'].plot();

# %% [markdown]
# #### 1.1.2 - TXT

# %%
petro_txt = pd.read_csv('/content/PETR4.txt')

# %%
petro_txt.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close       Volume
# 0  2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1  2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2  2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3  2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4  2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
petro_txt.Close.plot();

# %%
petro_txt['Date']
# Out:
# 0       2000-01-03
# 1       2000-01-04
# 2       2000-01-05
# 3       2000-01-06
# 4       2000-01-07
#            ...
# 5765    2022-12-13
# 5766    2022-12-14
# 5767    2022-12-15
# 5768    2022-12-16
# 5769    2022-12-19
# Name: Date, Length: 5770, dtype: object

# %%
petro_txt.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
petro_txt['Date'] = pd.to_datetime(petro_txt['Date'])

# %%
petro_txt.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
petro_txt.head()
# Out:
#         Date   Open   High    Low  Close  Adj Close       Volume
# 0 2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 1 2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2 2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 3 2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 4 2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
petro_txt.index = petro_txt['Date']

# %%
petro_txt.Close.plot();

# %%
lista = petro_txt.columns

# %%
petro_txt.shape
# Out:
# (5770, 7)

# %%
petro_txt.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
petro_txt.Close.max()
# Out:
# 52.5099983215332

# %%
petro_txt.Close.min()
# Out:
# 4.199999809265137

# %%
petro_txt.High.max()
# Out:
# 67.5

# %%
petro_txt.High.min()
# Out:
# 4.269999980926514

# %%
#media
petro_txt.Close.mean()
# Out:
# 18.983105641882382

# %%
# mediana
petro_txt.Close.median()
# Out:
# 19.255000114440918

# %%
#moda
petro_txt.High.mode()
# Out:
# 0    23.5
# Name: High, dtype: float64

# %%
#variancia
petro_txt.High.var()
# Out:
# 95.12231378704804

# %%
#desvio padrao
petro_txt.High.std()
# Out:
# 9.753066891344899

# %%
#pct_change - mudanção percentual
retornos = petro_txt.Close.pct_change()

# %%
retornos
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.055319
# 2000-01-05   -0.010090
# 2000-01-06   -0.003458
# 2000-01-07    0.004566
#                 ...
# 2022-12-13   -0.024676
# 2022-12-14   -0.079331
# 2022-12-15    0.026549
# 2022-12-16    0.000454
# 2022-12-19    0.013605
# Name: Close, Length: 5770, dtype: float64

# %%
retornos.std()
# Out:
# 0.02702581084493355

# %%
pd.DataFrame(retornos)
# Out:
#                Close
# Date
# 2000-01-03       NaN
# 2000-01-04 -0.055319
# 2000-01-05 -0.010090
# 2000-01-06 -0.003458
# 2000-01-07  0.004566
# ...              ...
# 2022-12-13 -0.024676
# 2022-12-14 -0.079331
# 2022-12-15  0.026549
# 2022-12-16  0.000454
# 2022-12-19  0.013605
#
# [5770 rows x 1 columns]

# %% [markdown]
# propriedades dos arquivos

# %%
profit = pd.read_csv('/content/PETR4_PROFIT.txt',sep=';',decimal=',')

# %%
profit.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
profit.index = pd.to_datetime(profit['Date'])

# %%
profit.head()
# Out:
#              Open   High    Low  Close  Adj Close       Volume
# Date
# 2000-01-03  5.875  5.875  5.875  5.875   1.872027  35389440000
# 2000-01-04  5.550  5.550  5.550  5.550   1.768469  28861440000
# 2000-01-05  5.494  5.494  5.494  5.494   1.750625  43033600000
# 2000-01-06  5.475  5.475  5.475  5.475   1.744570  34055680000
# 2000-01-07  5.500  5.500  5.500  5.500   1.752536  20912640000

# %%
profit.Close.plot();

# %% [markdown]
# #### 1.1.3 - XLSX

# %%
win = pd.read_excel('/content/WIN_MT5.xlsx',index_col='time')

# %%
win.dtypes
# Out:
# open            int64
# high            int64
# low             int64
# close           int64
# tick_volume     int64
# spread          int64
# real_volume     int64
# ticker         object
# dtype: object

# %%
win.head()
# Out:
#                        open    high     low   close  tick_volume  spread  \
# time
# 2022-12-27 09:00:00  111175  111260  111065  111185        15490       1
# 2022-12-27 09:01:00  111190  111370  111180  111215        21014       1
# 2022-12-27 09:02:00  111215  111225  111030  111050        15905       1
# 2022-12-27 09:03:00  111055  111055  110920  110925        16948       1
# 2022-12-27 09:04:00  110930  111070  110915  111030        13465       1
#
#                      real_volume ticker
# time
# 2022-12-27 09:00:00        30698   WIN$
# 2022-12-27 09:01:00        42351   WIN$
# 2022-12-27 09:02:00        30188   WIN$
# 2022-12-27 09:03:00        32705   WIN$
# 2022-12-27 09:04:00        24894   WIN$

# %%
win.close.plot();

# %% [markdown]
# ### 1.2 Obtenção de dados por API e bibliotecas
